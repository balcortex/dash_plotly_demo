# %%
import pandas as pd

# Load the CSV file
file_path = 'WEO2023_Extended_Data_Regions_Full_Sorted.csv'
df = pd.read_csv(file_path)

# Display the top 5 rows
df.head()
# Out:
#                  publication                  scenario category product  \
# 0  World Energy Outlook 2023  Stated Policies Scenario   Energy   Total
# 1  World Energy Outlook 2023  Stated Policies Scenario   Energy   Total
# 2  World Energy Outlook 2023  Stated Policies Scenario   Energy   Total
# 3  World Energy Outlook 2023  Stated Policies Scenario   Energy   Total
# 4  World Energy Outlook 2023  Stated Policies Scenario   Energy   Total
#
#                   flow unit         region  year     value
# 0  Total energy supply   PJ  North America  2010  112433.0
# 1  Total energy supply   PJ  North America  2015  112723.0
# 2  Total energy supply   PJ  North America  2021  111555.0
# 3  Total energy supply   PJ  North America  2022  114460.0
# 4  Total energy supply   PJ  North America  2030  108324.0

# %%
def get_total_energy_supply(df, region_name):
    """
    This function filters the dataset to return the Total Energy Supply (TES) 
    for a specific region, ensuring the output contains only the columns:
    region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing the TES data with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by category 'Energy'
    filtered_df = filtered_df[filtered_df['category'] == 'Energy']
    
    # Step 3: Filter by product 'Total'
    filtered_df = filtered_df[filtered_df['product'] == 'Total']
    
    # Step 4: Filter by flow 'Total energy supply'
    tes_df = filtered_df[filtered_df['flow'] == 'Total energy supply']
    
    # Step 5: Select only the necessary columns
    tes_df = tes_df[['region', 'scenario', 'year', 'value']]
    
    return tes_df

# Example usage:
region_name = 'India'
tes_df = get_total_energy_supply(df, region_name)

# Display the filtered DataFrame
tes_df
# Out:
#       region                    scenario  year    value
# 23904  India    Stated Policies Scenario  2010  27936.0
# 23905  India    Stated Policies Scenario  2015  34533.0
# 23906  India    Stated Policies Scenario  2021  39673.0
# 23907  India    Stated Policies Scenario  2022  41969.0
# 23908  India    Stated Policies Scenario  2030  53706.0
# 23909  India    Stated Policies Scenario  2035  60336.0
# 23910  India    Stated Policies Scenario  2040  64464.0
# 23911  India    Stated Policies Scenario  2045  68808.0
# 23912  India    Stated Policies Scenario  2050  72965.0
# 23913  India  Announced Pledges Scenario  2010  27936.0
# 23914  India  Announced Pledges Scenario  2015  34533.0
# 23915  India  Announced Pledges Scenario  2021  39673.0
# 23916  India  Announced Pledges Scenario  2022  41969.0
# 23917  India  Announced Pledges Scenario  2030  47614.0
# 23918  India  Announced Pledges Scenario  2035  49812.0
# 23919  India  Announced Pledges Scenario  2040  53379.0
# 23920  India  Announced Pledges Scenario  2045  57285.0
# 23921  India  Announced Pledges Scenario  2050  60292.0

# %%
def get_co2_total(df, region_name):
    """
    This function filters the dataset to return the CO2 total 
    for a specific region, ensuring the output contains only the columns:
    region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing the CO2 total data with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by category 'CO2 total'
    filtered_df = filtered_df[filtered_df['category'] == 'CO2 total']
    
    # Step 3: Filter by product 'Total'
    filtered_df = filtered_df[filtered_df['product'] == 'Total']
    
    # Step 4: Filter by flow 'Total energy supply'
    co2_df = filtered_df[filtered_df['flow'] == 'Total energy supply']
    
    # Step 5: Select only the necessary columns
    co2_df = co2_df[['region', 'scenario', 'year', 'value']]
    
    return co2_df

# Example usage:
co2_df = get_co2_total(df, region_name)

# Display the filtered DataFrame
co2_df
# Out:
#       region                    scenario  year    value
# 25266  India    Stated Policies Scenario  2010  1685.48
# 25267  India    Stated Policies Scenario  2015  2175.31
# 25268  India    Stated Policies Scenario  2021  2461.50
# 25269  India    Stated Policies Scenario  2022  2627.27
# 25270  India    Stated Policies Scenario  2030  3251.96
# 25271  India    Stated Policies Scenario  2035  3450.24
# 25272  India    Stated Policies Scenario  2040  3393.90
# 25273  India    Stated Policies Scenario  2045  3352.94
# 25274  India    Stated Policies Scenario  2050  3362.77
# 25275  India  Announced Pledges Scenario  2010  1685.48
# 25276  India  Announced Pledges Scenario  2015  2175.31
# 25277  India  Announced Pledges Scenario  2021  2461.50
# 25278  India  Announced Pledges Scenario  2022  2627.27
# 25279  India  Announced Pledges Scenario  2030  2874.94
# 25280  India  Announced Pledges Scenario  2035  2515.47
# 25281  India  Announced Pledges Scenario  2040  2070.14
# 25282  India  Announced Pledges Scenario  2045  1755.42
# 25283  India  Announced Pledges Scenario  2050  1480.78

# %%
def get_gdp_per_capita(df, region_name):
    """
    This function filters the dataset to return the GDP per capita 
    for a specific region, ensuring the output contains only the columns:
    region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing the GDP per capita data with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by flow 'GDP per capita'
    gdp_df = filtered_df[filtered_df['flow'] == 'GDP per capita']
    
    # Step 3: Select only the necessary columns
    gdp_df = gdp_df[['region', 'scenario', 'year', 'value']]
    
    return gdp_df

# Example usage:
gdp_df = get_gdp_per_capita(df, region_name)

# Display the filtered DataFrame
gdp_df
# Out:
#       region                    scenario  year     value
# 25680  India    Stated Policies Scenario  2010   4909.76
# 25681  India    Stated Policies Scenario  2015   6390.08
# 25682  India    Stated Policies Scenario  2021   7884.10
# 25683  India    Stated Policies Scenario  2022   8365.52
# 25684  India    Stated Policies Scenario  2030  12876.10
# 25685  India    Stated Policies Scenario  2035  16176.10
# 25686  India    Stated Policies Scenario  2040  19540.60
# 25687  India    Stated Policies Scenario  2045  23173.50
# 25688  India    Stated Policies Scenario  2050  27073.20
# 25689  India  Announced Pledges Scenario  2010   4909.76
# 25690  India  Announced Pledges Scenario  2015   6390.08
# 25691  India  Announced Pledges Scenario  2021   7884.10
# 25692  India  Announced Pledges Scenario  2022   8365.52
# 25693  India  Announced Pledges Scenario  2030  12876.10
# 25694  India  Announced Pledges Scenario  2035  16176.10
# 25695  India  Announced Pledges Scenario  2040  19540.60
# 25696  India  Announced Pledges Scenario  2045  23173.50
# 25697  India  Announced Pledges Scenario  2050  27073.20

# %%
def get_ee1(df, region_name):
    """
    This function calculates ee1 by summing 'Services' and 'Residential'
    for 'Floorspace' in the product column, filtered by the given region,
    ensuring the output contains only the columns: region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing ee1 with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by product 'Floorspace'
    filtered_df = filtered_df[filtered_df['product'] == 'Floorspace']
    
    # Step 3: Extract 'Services' and 'Residential' from the flow column
    services_df = filtered_df[filtered_df['flow'] == 'Services']
    residential_df = filtered_df[filtered_df['flow'] == 'Residential']
    
    # Step 4: Summing Services and Residential to calculate ee1
    ee1_df = services_df.copy()
    ee1_df['value'] = services_df['value'] + residential_df['value'].values
    
    # Step 5: Select only the necessary columns
    ee1_df = ee1_df[['region', 'scenario', 'year', 'value']]
    
    return ee1_df

# %%
ee1_df=get_ee1(df,region_name)
ee1_df
# Out:
#       region                    scenario  year     value
# 25716  India    Stated Policies Scenario  2010  14135.40
# 25717  India    Stated Policies Scenario  2015  16124.20
# 25718  India    Stated Policies Scenario  2021  18692.69
# 25719  India    Stated Policies Scenario  2022  19224.03
# 25720  India    Stated Policies Scenario  2030  25647.88
# 25721  India    Stated Policies Scenario  2035  31203.00
# 25722  India    Stated Policies Scenario  2040  37366.62
# 25723  India    Stated Policies Scenario  2045  44025.21
# 25724  India    Stated Policies Scenario  2050  50567.89
# 25725  India  Announced Pledges Scenario  2010  14135.40
# 25726  India  Announced Pledges Scenario  2015  16124.20
# 25727  India  Announced Pledges Scenario  2021  18692.69
# 25728  India  Announced Pledges Scenario  2022  19224.03
# 25729  India  Announced Pledges Scenario  2030  25647.88
# 25730  India  Announced Pledges Scenario  2035  31203.00
# 25731  India  Announced Pledges Scenario  2040  37366.62
# 25732  India  Announced Pledges Scenario  2045  44025.21
# 25733  India  Announced Pledges Scenario  2050  50567.89

# %%
def get_ee2(df, region_name):
    """
    This function calculates ee2 by summing 'Road passenger light duty vehicle'
    and 'Road freight trucks' for 'Activity of stock' in the category column,
    filtered by the given region, ensuring the output contains only the columns:
    region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing ee2 with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by category 'Activity of stock'
    filtered_df = filtered_df[filtered_df['category'] == 'Activity of stock']
    
    # Step 3: Extract 'Road passenger light duty vehicle' and 'Road freight trucks' from the flow column
    passenger_df = filtered_df[filtered_df['flow'] == 'Road passenger light duty vehicle']
    freight_df = filtered_df[filtered_df['flow'] == 'Road freight trucks']
    
    # Step 4: Summing Road passenger light duty vehicle and Road freight trucks to calculate ee2
    ee2_df = passenger_df.copy()
    ee2_df['value'] = passenger_df['value'] + freight_df['value'].values
    
    # Step 5: Select only the necessary columns
    ee2_df = ee2_df[['region', 'scenario', 'year', 'value']]
    
    return ee2_df

# %%
ee2_df=get_ee2(df,region_name)
ee2_df
# Out:
#       region                    scenario  year     value
# 25842  India    Stated Policies Scenario  2010   1715.08
# 25843  India    Stated Policies Scenario  2015   2387.87
# 25844  India    Stated Policies Scenario  2021   2965.88
# 25845  India    Stated Policies Scenario  2022   3325.61
# 25846  India    Stated Policies Scenario  2030   5257.26
# 25847  India    Stated Policies Scenario  2035   6890.46
# 25848  India    Stated Policies Scenario  2040   8813.77
# 25849  India    Stated Policies Scenario  2045  10544.22
# 25850  India    Stated Policies Scenario  2050  11794.03
# 25851  India  Announced Pledges Scenario  2010   1715.08
# 25852  India  Announced Pledges Scenario  2015   2387.87
# 25853  India  Announced Pledges Scenario  2021   2965.88
# 25854  India  Announced Pledges Scenario  2022   3325.61
# 25855  India  Announced Pledges Scenario  2030   5068.57
# 25856  India  Announced Pledges Scenario  2035   6619.72
# 25857  India  Announced Pledges Scenario  2040   8524.06
# 25858  India  Announced Pledges Scenario  2045  10291.66
# 25859  India  Announced Pledges Scenario  2050  11691.09

# %%
def get_ee3(df, region_name):
    """
    This function calculates ee3 by summing 'Primary chemicals', 'Crude steel',
    'Cement', and 'Aluminium' for 'Industrial material production' in the category column,
    filtered by the given region, ensuring the output contains only the columns:
    region, scenario, year, and value.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame containing ee3 with the relevant columns.
    """
    # Step 1: Filter by region
    filtered_df = df[df['region'] == region_name]
    
    # Step 2: Filter by category 'Industrial material production'
    filtered_df = filtered_df[filtered_df['category'] == 'Industrial material production']
    
    # Step 3: Extract relevant products
    chemicals_df = filtered_df[filtered_df['product'] == 'Primary chemicals']
    steel_df = filtered_df[filtered_df['product'] == 'Crude steel']
    cement_df = filtered_df[filtered_df['product'] == 'Cement']
    aluminium_df = filtered_df[filtered_df['product'] == 'Aluminium']
    
    # Step 4: Summing the values to calculate ee3
    ee3_df = chemicals_df.copy()
    ee3_df['value'] = (chemicals_df['value'].values +
                       steel_df['value'].values +
                       cement_df['value'].values +
                       aluminium_df['value'].values)
    
    # Step 5: Select only the necessary columns
    ee3_df = ee3_df[['region', 'scenario', 'year', 'value']]
    
    return ee3_df

# %%
ee3_df=get_ee3(df,region_name)
ee3_df
# Out:
#       region                    scenario  year    value
# 25770  India    Stated Policies Scenario  2010   311.75
# 25771  India    Stated Policies Scenario  2015   377.27
# 25772  India    Stated Policies Scenario  2021   504.27
# 25773  India    Stated Policies Scenario  2022   531.75
# 25774  India    Stated Policies Scenario  2030   758.60
# 25775  India    Stated Policies Scenario  2035   920.03
# 25776  India    Stated Policies Scenario  2040  1060.25
# 25777  India    Stated Policies Scenario  2045  1176.26
# 25778  India    Stated Policies Scenario  2050  1278.63
# 25779  India  Announced Pledges Scenario  2010   311.75
# 25780  India  Announced Pledges Scenario  2015   377.27
# 25781  India  Announced Pledges Scenario  2021   504.27
# 25782  India  Announced Pledges Scenario  2022   531.75
# 25783  India  Announced Pledges Scenario  2030   747.85
# 25784  India  Announced Pledges Scenario  2035   871.51
# 25785  India  Announced Pledges Scenario  2040   965.96
# 25786  India  Announced Pledges Scenario  2045  1042.86
# 25787  India  Announced Pledges Scenario  2050  1114.30

# %%
import pandas as pd

def create_df_ee(df, region_name):
    """
    This function creates a new DataFrame (df_ee) that combines ee1, ee2, and ee3 
    into a single DataFrame for the specified region. The resulting DataFrame contains 
    the columns: region, scenario, year, ee1, ee2, and ee3.

    Parameters:
    - df: The original DataFrame containing the data.
    - region_name: The name of the region you want to filter by.

    Returns:
    - A DataFrame (df_ee) containing the combined data for ee1, ee2, and ee3.
    """
    # Calculate ee1, ee2, ee3
    ee1_df = get_ee1(df, region_name)
    ee2_df = get_ee2(df, region_name)
    ee3_df = get_ee3(df, region_name)
    
    # Merge dataframes on common keys (region, scenario, year)
    df_ee = ee1_df.merge(ee2_df, on=['region', 'scenario', 'year'], suffixes=('_ee1', '_ee2'))
    df_ee = df_ee.merge(ee3_df, on=['region', 'scenario', 'year'])
    
    # Rename columns for clarity
    df_ee.rename(columns={
        'value_ee1': 'ee1',
        'value_ee2': 'ee2',
        'value': 'ee3'
    }, inplace=True)
    
    return df_ee

# Example usage:

df_ee = create_df_ee(df, region_name)

# Display the resulting DataFrame with ee1, ee2, and ee3 for each year and scenario
df_ee
# Out:
#    region                    scenario  year       ee1       ee2      ee3
# 0   India    Stated Policies Scenario  2010  14135.40   1715.08   311.75
# 1   India    Stated Policies Scenario  2015  16124.20   2387.87   377.27
# 2   India    Stated Policies Scenario  2021  18692.69   2965.88   504.27
# 3   India    Stated Policies Scenario  2022  19224.03   3325.61   531.75
# 4   India    Stated Policies Scenario  2030  25647.88   5257.26   758.60
# 5   India    Stated Policies Scenario  2035  31203.00   6890.46   920.03
# 6   India    Stated Policies Scenario  2040  37366.62   8813.77  1060.25
# 7   India    Stated Policies Scenario  2045  44025.21  10544.22  1176.26
# 8   India    Stated Policies Scenario  2050  50567.89  11794.03  1278.63
# 9   India  Announced Pledges Scenario  2010  14135.40   1715.08   311.75
# 10  India  Announced Pledges Scenario  2015  16124.20   2387.87   377.27
# 11  India  Announced Pledges Scenario  2021  18692.69   2965.88   504.27
# 12  India  Announced Pledges Scenario  2022  19224.03   3325.61   531.75
# 13  India  Announced Pledges Scenario  2030  25647.88   5068.57   747.85
# 14  India  Announced Pledges Scenario  2035  31203.00   6619.72   871.51
# 15  India  Announced Pledges Scenario  2040  37366.62   8524.06   965.96
# 16  India  Announced Pledges Scenario  2045  44025.21  10291.66  1042.86
# 17  India  Announced Pledges Scenario  2050  50567.89  11691.09  1114.30

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

def calculate_ee_from_df_ee(df_ee):
    """
    This function calculates the Energy Efficiency (EE) using PCA on ee1, ee2, and ee3
    from the DataFrame (df_ee), ensuring the output contains only the columns:
    region, scenario, year, and EE.

    Parameters:
    - df_ee: The DataFrame containing ee1, ee2, and ee3.

    Returns:
    - A DataFrame with the calculated EE for each year and scenario with the relevant columns.
    """
    # Step 1: Standardization
    scaler = StandardScaler()
    standardized_data = scaler.fit_transform(df_ee[['ee1', 'ee2', 'ee3']])
    
    # Step 2: Perform PCA
    pca = PCA(n_components=1)
    df_ee['EE'] = pca.fit_transform(standardized_data)
    
    # Select only the necessary columns
    df_ee = df_ee[['region', 'scenario', 'year', 'EE']]
    
    return df_ee

# Example usage:
ee_final_df = calculate_ee_from_df_ee(df_ee)

# Display the resulting DataFrame with EE for each year and scenario
ee_final_df
# Out:
#    region                    scenario  year        EE
# 0   India    Stated Policies Scenario  2010 -2.173138
# 1   India    Stated Policies Scenario  2015 -1.846592
# 2   India    Stated Policies Scenario  2021 -1.395179
# 3   India    Stated Policies Scenario  2022 -1.259502
# 4   India    Stated Policies Scenario  2030 -0.216952
# 5   India    Stated Policies Scenario  2035  0.614285
# 6   India    Stated Policies Scenario  2040  1.483353
# 7   India    Stated Policies Scenario  2045  2.298812
# 8   India    Stated Policies Scenario  2050  3.003471
# 9   India  Announced Pledges Scenario  2010 -2.173138
# 10  India  Announced Pledges Scenario  2015 -1.846592
# 11  India  Announced Pledges Scenario  2021 -1.395179
# 12  India  Announced Pledges Scenario  2022 -1.259502
# 13  India  Announced Pledges Scenario  2030 -0.268269
# 14  India  Announced Pledges Scenario  2035  0.479577
# 15  India  Announced Pledges Scenario  2040  1.261015
# 16  India  Announced Pledges Scenario  2045  2.010496
# 17  India  Announced Pledges Scenario  2050  2.683037

# %%
import pandas as pd

def create_tes_model_df(tes_df, co2_df, gdp_df, ee_final_df):
    """
    This function merges the TES, CO2 total, GDP per capita, and EE DataFrames
    into a single DataFrame (df_tes_model) for modeling.

    Parameters:
    - tes_df: DataFrame containing TES values.
    - co2_df: DataFrame containing CO2 total values.
    - gdp_df: DataFrame containing GDP per capita values.
    - ee_final_df: DataFrame containing EE values.

    Returns:
    - A DataFrame (df_tes_model) containing all the combined data.
    """
    # Merge dataframes on common keys (region, scenario, year)
    df_tes_model = tes_df.merge(co2_df[['region', 'scenario', 'year', 'value']], on=['region', 'scenario', 'year'], suffixes=('', '_CO2'))
    df_tes_model = df_tes_model.merge(gdp_df[['region', 'scenario', 'year', 'value']], on=['region', 'scenario', 'year'], suffixes=('', '_GDP'))
    df_tes_model = df_tes_model.merge(ee_final_df[['region', 'scenario', 'year', 'EE']], on=['region', 'scenario', 'year'])
    
    # Rename columns for clarity
    df_tes_model.rename(columns={
        'value': 'TES',
        'value_CO2': 'CO2_total',
        'value_GDP': 'GDP_per_capita'
    }, inplace=True)
    
    return df_tes_model

# Example usage:
df_tes_model = create_tes_model_df(tes_df, co2_df, gdp_df, ee_final_df)

# Display the resulting DataFrame
df_tes_model.head(18)
# Out:
#    region                    scenario  year      TES  CO2_total  \
# 0   India    Stated Policies Scenario  2010  27936.0    1685.48
# 1   India    Stated Policies Scenario  2015  34533.0    2175.31
# 2   India    Stated Policies Scenario  2021  39673.0    2461.50
# 3   India    Stated Policies Scenario  2022  41969.0    2627.27
# 4   India    Stated Policies Scenario  2030  53706.0    3251.96
# 5   India    Stated Policies Scenario  2035  60336.0    3450.24
# 6   India    Stated Policies Scenario  2040  64464.0    3393.90
# 7   India    Stated Policies Scenario  2045  68808.0    3352.94
# 8   India    Stated Policies Scenario  2050  72965.0    3362.77
# 9   India  Announced Pledges Scenario  2010  27936.0    1685.48
# 10  India  Announced Pledges Scenario  2015  34533.0    2175.31
# 11  India  Announced Pledges Scenario  2021  39673.0    2461.50
# 12  India  Announced Pledges Scenario  2022  41969.0    2627.27
# 13  India  Announced Pledges Scenario  2030  47614.0    2874.94
# 14  India  Announced Pledges Scenario  2035  49812.0    2515.47
# 15  India  Announced Pledges Scenario  2040  53379.0    2070.14
# 16  India  Announced Pledges Scenario  2045  57285.0    1755.42
# 17  India  Announced Pledges Scenario  2050  60292.0    1480.78
#
#     GDP_per_capita        EE
# 0          4909.76 -2.173138
# 1          6390.08 -1.846592
# 2          7884.10 -1.395179
# 3          8365.52 -1.259502
# 4         12876.10 -0.216952
# 5         16176.10  0.614285
# 6         19540.60  1.483353
# 7         23173.50  2.298812
# 8         27073.20  3.003471
# 9          4909.76 -2.173138
# 10         6390.08 -1.846592
# 11         7884.10 -1.395179
# 12         8365.52 -1.259502
# 13        12876.10 -0.268269
# 14        16176.10  0.479577
# 15        19540.60  1.261015
# 16        23173.50  2.010496
# 17        27073.20  2.683037

# %%
def create_synthetic_average(df_tes_model):
    """
    This function calculates the synthetic average for each year by averaging
    the TES, CO2_total, GDP_per_capita, and EE values across the two scenarios.

    Parameters:
    - df_tes_model: The DataFrame containing TES, CO2_total, GDP_per_capita, and EE data for both scenarios.

    Returns:
    - A new DataFrame containing the average values for each year.
    """
    avg_df = df_tes_model.groupby('year').agg(
        avg_TES=('TES', 'mean'),
        avg_CO2_total=('CO2_total', 'mean'),
        avg_GDP_per_capita=('GDP_per_capita', 'mean'),
        avg_EE=('EE', 'mean')
    ).reset_index()
    
    return avg_df

# Example usage:
avg_df = create_synthetic_average(df_tes_model)

# Display the synthetic average DataFrame
avg_df
# Out:
#    year  avg_TES  avg_CO2_total  avg_GDP_per_capita    avg_EE
# 0  2010  27936.0       1685.480             4909.76 -2.173138
# 1  2015  34533.0       2175.310             6390.08 -1.846592
# 2  2021  39673.0       2461.500             7884.10 -1.395179
# 3  2022  41969.0       2627.270             8365.52 -1.259502
# 4  2030  50660.0       3063.450            12876.10 -0.242611
# 5  2035  55074.0       2982.855            16176.10  0.546931
# 6  2040  58921.5       2732.020            19540.60  1.372184
# 7  2045  63046.5       2554.180            23173.50  2.154654
# 8  2050  66628.5       2421.775            27073.20  2.843254

# %%
from sklearn.preprocessing import StandardScaler

def standardize_variables(avg_df):
    """
    This function standardizes the variables in the average DataFrame.

    Parameters:
    - avg_df: The DataFrame containing the synthetic average data.

    Returns:
    - A DataFrame with standardized values for CO2_total, GDP_per_capita, and EE.
    """
    scaler = StandardScaler()
    avg_df[['avg_CO2_total', 'avg_GDP_per_capita', 'avg_EE']] = scaler.fit_transform(
        avg_df[['avg_CO2_total', 'avg_GDP_per_capita', 'avg_EE']]
    )
    
    return avg_df

# Example usage:
avg_df_standardized = standardize_variables(avg_df)

# Display the standardized DataFrame
avg_df_standardized
# Out:
#    year  avg_TES  avg_CO2_total  avg_GDP_per_capita    avg_EE
# 0  2010  27936.0      -2.126074           -1.223625 -1.263281
# 1  2015  34533.0      -0.882102           -1.025304 -1.073455
# 2  2021  39673.0      -0.155294           -0.825148 -0.811041
# 3  2022  41969.0       0.265696           -0.760651 -0.732169
# 4  2030  50660.0       1.373418           -0.156361 -0.141034
# 5  2035  55074.0       1.168739            0.285746  0.317940
# 6  2040  58921.5       0.531719            0.736494  0.797673
# 7  2045  63046.5       0.080076            1.223200  1.252536
# 8  2050  66628.5      -0.256179            1.745650  1.652831

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def fit_best_tes_model(avg_df, max_degree=4):
    """
    This function fits several regression models (linear and polynomial of different degrees)
    to predict TES as a function of CO2_total, GDP_per_capita, and EE, and selects the best one
    based on Mean Squared Error (MSE).

    Parameters:
    - avg_df: The DataFrame containing the synthetic average data with standardized variables.
    - max_degree: The maximum degree of the polynomial regression to consider.

    Returns:
    - The best fitted regression model, along with its performance metrics (MSE and R-squared).
    """
    X = avg_df[['avg_CO2_total', 'avg_GDP_per_capita', 'avg_EE']]
    y = avg_df['avg_TES']
    
    best_mse = np.inf
    best_model = None
    best_degree = 0
    best_r2 = 0
    
    for degree in range(1, max_degree + 1):
        if degree == 1:
            # Linear regression model
            poly = PolynomialFeatures(degree=1, include_bias=False)
        else:
            # Polynomial regression model
            poly = PolynomialFeatures(degree=degree)
        
        X_poly = poly.fit_transform(X)
        model = LinearRegression()
        model.fit(X_poly, y)
        
        y_pred = model.predict(X_poly)
        mse = mean_squared_error(y, y_pred)
        r2 = r2_score(y, y_pred)
        
        print(f"Degree {degree}: MSE = {mse}, R-squared = {r2}")
        
        if mse < best_mse:
            best_mse = mse
            best_model = model
            best_degree = degree
            best_r2 = r2
    
    print(f"\nBest Model: Degree {best_degree}")
    print(f"Best Model MSE: {best_mse}")
    print(f"Best Model R-squared: {best_r2}")
    
    return best_model, best_degree, best_mse, best_r2

# Example usage:
best_model, best_degree, best_mse, best_r2 = fit_best_tes_model(avg_df_standardized)
# Out:
# Degree 1: MSE = 182165.70554265287, R-squared = 0.998857370045739
# Degree 2: MSE = 5.88217324482153e-23, R-squared = 1.0
# Degree 3: MSE = 3.529303946892918e-23, R-squared = 1.0
# Degree 4: MSE = 2.470512762825043e-22, R-squared = 1.0
#
# Best Model: Degree 3
# Best Model MSE: 3.529303946892918e-23
# Best Model R-squared: 1.0

# %%
def predict_tes_using_best_model(avg_df, best_model, best_degree):
    """
    This function predicts TES using the best fitted model for the synthetic average scenario.

    Parameters:
    - avg_df: The DataFrame containing the synthetic average data with standardized variables.
    - best_model: The best regression model fitted to the data.
    - best_degree: The degree of the polynomial used in the best model.

    Returns:
    - A DataFrame with the predicted TES values.
    """
    X = avg_df[['avg_CO2_total', 'avg_GDP_per_capita', 'avg_EE']]
    poly = PolynomialFeatures(degree=best_degree)
    X_poly = poly.fit_transform(X)
    
    avg_df['predicted_TES'] = best_model.predict(X_poly)
    
    return avg_df

# Predict TES using the best model
avg_df_with_predictions = predict_tes_using_best_model(avg_df_standardized, best_model, best_degree)

# %%
from scipy.optimize import minimize
from sklearn.metrics import mean_squared_error

def objective_function(params, avg_df, df_tes_model):
    """
    Objective function for optimization to find the best multipliers a and b.

    Parameters:
    - params: The multipliers [a, b] being optimized.
    - avg_df: The DataFrame containing the predicted TES for the average scenario.
    - df_tes_model: The original DataFrame with actual TES values for both scenarios.

    Returns:
    - The total mean squared error for the STEPS and APS scenarios.
    """
    a, b = params
    mse_steps = mse_aps = 0
    
    for scenario, multiplier in [('Stated Policies Scenario', a), ('Announced Pledges Scenario', b)]:
        actual_tes = df_tes_model[df_tes_model['scenario'] == scenario]['TES'].values
        predicted_tes = avg_df['predicted_TES'].values * multiplier
        mse = mean_squared_error(actual_tes, predicted_tes)
        
        if scenario == 'Stated Policies Scenario':
            mse_steps = mse
        else:
            mse_aps = mse
    
    total_mse = mse_steps + mse_aps
    return total_mse

# Set the initial guess for the multipliers a and b
initial_guess = [1.0, 1.0]

# Perform the optimization
result = minimize(objective_function, initial_guess, args=(avg_df_with_predictions, df_tes_model), method='BFGS')

# Extract the optimal multipliers
a_opt, b_opt = result.x

print(f"Optimal multiplier a: {a_opt}")
print(f"Optimal multiplier b: {b_opt}")
# Out:
# Optimal multiplier a: 1.0682691581358053
# Optimal multiplier b: 0.9317308270575174

# %%
def apply_multipliers_with_difference(avg_df, df_tes_model, a, b):
    """
    Apply the optimized multipliers to predict TES for both scenarios and calculate the percentage difference.

    Parameters:
    - avg_df: The DataFrame containing the predicted TES for the average scenario.
    - df_tes_model: The original DataFrame with actual TES values for both scenarios.
    - a: Optimized multiplier for STEPS.
    - b: Optimized multiplier for APS.

    Returns:
    - A DataFrame with the adjusted TES predictions for both scenarios and the percentage difference.
    """
    df_tes_model['predicted_TES_adjusted'] = 0
    
    for scenario, multiplier in [('Stated Policies Scenario', a), ('Announced Pledges Scenario', b)]:
        df_tes_model.loc[df_tes_model['scenario'] == scenario, 'predicted_TES_adjusted'] = avg_df['predicted_TES'].values * multiplier
    
    # Calculate percentage difference
    df_tes_model['percentage_difference'] = 100 * (df_tes_model['predicted_TES_adjusted'] - df_tes_model['TES']) / df_tes_model['TES']
    
    return df_tes_model

# Apply the optimized multipliers and calculate percentage difference
df_tes_model_adjusted = apply_multipliers_with_difference(avg_df_with_predictions, df_tes_model, a_opt, b_opt)

# Display the adjusted DataFrame with percentage difference
df_tes_model_adjusted[['year', 'scenario', 'TES', 'predicted_TES_adjusted', 'percentage_difference']]
# Out:
# C:\Users\mehdik\AppData\Local\Temp\ipykernel_27416\1693357440.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[29843.16720168 36890.5388379  42381.44231072 44834.1882978
#  54118.51555116 58833.85561517 62944.0212011  67350.63147841
#  71177.17160285]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_tes_model.loc[df_tes_model['scenario'] == scenario, 'predicted_TES_adjusted'] = avg_df['predicted_TES'].values * multiplier
#     year                    scenario      TES  predicted_TES_adjusted  \
# 0   2010    Stated Policies Scenario  27936.0            29843.167202
# 1   2015    Stated Policies Scenario  34533.0            36890.538838
# 2   2021    Stated Policies Scenario  39673.0            42381.442311
# 3   2022    Stated Policies Scenario  41969.0            44834.188298
# 4   2030    Stated Policies Scenario  53706.0            54118.515551
# 5   2035    Stated Policies Scenario  60336.0            58833.855615
# 6   2040    Stated Policies Scenario  64464.0            62944.021201
# 7   2045    Stated Policies Scenario  68808.0            67350.631478
# 8   2050    Stated Policies Scenario  72965.0            71177.171603
# 9   2010  Announced Pledges Scenario  27936.0            26028.832385
# 10  2015  Announced Pledges Scenario  34533.0            32175.460651
# 11  2021  Announced Pledges Scenario  39673.0            36964.557102
# 12  2022  Announced Pledges Scenario  41969.0            39103.811081
# 13  2030  Announced Pledges Scenario  47614.0            47201.483699
# 14  2035  Announced Pledges Scenario  49812.0            51314.143569
# 15  2040  Announced Pledges Scenario  53379.0            54898.977926
# 16  2045  Announced Pledges Scenario  57285.0            58742.367588
# 17  2050  Announced Pledges Scenario  60292.0            62079.827411
#
#     percentage_difference
# 0                6.826916
# 1                6.826916
# 2                6.826916
# 3                6.826916
# 4                0.768100
# 5               -2.489632
# 6               -2.357872
# 7               -2.118022
# 8               -2.450255
# 9               -6.826917
# 10              -6.826917
# 11              -6.826917
# 12              -6.826917
# 13              -0.866376
# 14               3.015626
# 15               2.847520
# 16               2.544065
# 17               2.965281

# %%
def plot_tes_vs_predicted(df_tes_model_adjusted, region_name):
    """
    This function creates a plot to visualize the actual TES values against the predicted TES adjusted values,
    and includes the region name in the title.

    Parameters:
    - df_tes_model_adjusted: The DataFrame containing both the actual TES and the predicted TES adjusted values.
    - region_name: The name of the region to include in the plot title.
    """
    plt.figure(figsize=(12, 6))

    # Plot actual TES values
    for scenario in df_tes_model_adjusted['scenario'].unique():
        scenario_df = df_tes_model_adjusted[df_tes_model_adjusted['scenario'] == scenario]
        plt.plot(scenario_df['year'], scenario_df['TES'], label=f'Actual TES - {scenario}', marker='o')
    
    # Plot predicted TES adjusted values
    for scenario in df_tes_model_adjusted['scenario'].unique():
        scenario_df = df_tes_model_adjusted[df_tes_model_adjusted['scenario'] == scenario]
        plt.plot(scenario_df['year'], scenario_df['predicted_TES_adjusted'], label=f'Predicted TES Adjusted - {scenario}', linestyle='--', marker='x')
    
    plt.xlabel('Year')
    plt.ylabel('TES')
    plt.title(f'Actual TES vs Predicted TES Adjusted for {region_name}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
plot_tes_vs_predicted(df_tes_model_adjusted, region_name)
